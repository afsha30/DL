# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([[0,0],[0,1],[1,0],[1,1]])
y=[0,0,0,1]
area = 200
fig = plt.figure(figsize=(4,4))
plt.title('AND Gate', fontsize=20)
# color red: is class 1 and color blue is class 0.
for i in range(4):
    if y[i]==1:
        co='r'
    else:
        co='b'
    plt.scatter(x[i][0],x[i][1],s=area,c=co)
    plt.plot([0,1.1],[1.1,0])
    
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([[0,0],[0,1],[1,0],[1,1]])
y=[0,1,1,1]
area = 200
fig = plt.figure(figsize=(4,4))
plt.title('OR Gate', fontsize=20)
# color red: is class 1 and color blue is class 0.
for i in range(4):
    if y[i]==1:
        co='r'
    else:
        co='b'
    plt.scatter(x[i][0],x[i][1],s=area,c=co)
    plt.plot([0,0.9],[0.9,0])
plt.show()

# %%
import matplotlib.pyplot as plot
import numpy as np
input = np.array([[0,0],[0,1],[1,0],[1,1]])
l1 = [0,1,1,0]
l2 = [0,1,0,1]
orr =[]
p=[]
def ORgate(l1,l2,orr,p):
    for i in range(len(l1)):
        if l1[i]==0 and l2[i]==0:
            orr.append(0)
        else:
            orr.append(1)
    print(orr)
    for i in range(len(orr)):
        if i != 0:
            print(l1[i],l2[i],"--->",l1[i]+l2[i])
            a = l1[i]+l2[i]
            p.append(a)
    arr = []
    for i in range(len(l1)):
        if(l1[i]+l2[i] == min(p)):
            x = l1[i]
            y= l2[i]
            arr.append([x,y])
    return arr
ann = []
p =[]
def ANDgate(l1,l2,ann,p):
    xy = []
    for i in range(len(l1)):
        if l1[i] == 1 and l2[i] == 1:
            ann.append(1)
        else:
            ann.append(0)
    print(ann)
    for i in range(len(ann)):
        print(l1[i],l2[i],"--->",l1[i]+l2[i])
        p.append(l1[i]+l2[i])
    for i in range(len(l1)):
        if(l1[i]+l2[i] == max(p)):
            x = l1[i]
            y = l2[i]
            return x,y
    

            
    
        
arr = ORgate(l1,l2,orr,p)
x,y = ANDgate(l1,l2,ann,p)
xy = [x,y]
print(xy)
plot.scatter(arr[0],arr[1],color = "green")
plot.plot(arr[0],arr[1],color = "blue")
plot.scatter(x,y,color = "red")
plot.show()
# Out:
# [0, 1, 1, 1]
# 1 1 ---> 2
# 1 0 ---> 1
# 0 1 ---> 1
# [0, 1, 0, 0]
# 0 0 ---> 0
# 1 1 ---> 2
# 1 0 ---> 1
# 0 1 ---> 1
# [1, 1]
